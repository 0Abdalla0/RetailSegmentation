# %%
import pandas as pd
import numpy as py

# %%
df = pd.read_csv("data.csv")

# %%
df.info()
print(df.isnull().sum())
df.describe(include='all')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2240 entries, 0 to 2239
# Data columns (total 27 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               2240 non-null   int64
#  1   birth_year                2240 non-null   int64
#  2   education_level           2199 non-null   object
#  3   marital_status            2240 non-null   object
#  4   annual_income             2173 non-null   float64
#  5   num_children              2240 non-null   int64
#  6   num_teenagers             2196 non-null   float64
#  7   signup_date               2240 non-null   object
#  8   days_since_last_purchase  2240 non-null   int64
#  9   has_recent_complaint      2240 non-null   int64
#  10  spend_wine                2240 non-null   int64
#  11  spend_fruits              2240 non-null   int64
#  12  spend_meat                2240 non-null   int64
#  13  spend_fish                2240 non-null   int64
# ...

# %%
df=df.dropna()
df = df.drop_duplicates()
df
# Out:
#       customer_id  birth_year education_level marital_status  annual_income  \
# 0            5524        1957      Graduation         Single        58138.0
# 1            2174        1954      Graduation         Single        46344.0
# 2            4141        1965      Graduation       Together        71613.0
# 3            6182        1984      Graduation       Together        26646.0
# 4            5324        1981             PhD        Married        58293.0
# ...           ...         ...             ...            ...            ...
# 2235        10870        1967      Graduation        Married        61223.0
# 2236         4001        1946             PhD       Together        64014.0
# 2237         7270        1981      Graduation       Divorced        56981.0
# 2238         8235        1956          Master       Together        69245.0
# 2239         9405        1954             PhD        Married        52869.0
#
# ...

# %%
df = df.drop(columns="customer_id")
df = df.drop(columns="signup_date")

# %%
df
# Out:
#       birth_year education_level marital_status  annual_income  num_children  \
# 0           1957      Graduation         Single        58138.0             0
# 1           1954      Graduation         Single        46344.0             1
# 2           1965      Graduation       Together        71613.0             0
# 3           1984      Graduation       Together        26646.0             1
# 4           1981             PhD        Married        58293.0             1
# ...          ...             ...            ...            ...           ...
# 2235        1967      Graduation        Married        61223.0             0
# 2236        1946             PhD       Together        64014.0             2
# 2237        1981      Graduation       Divorced        56981.0             0
# 2238        1956          Master       Together        69245.0             0
# 2239        1954             PhD        Married        52869.0             1
#
# ...

# %%
#combine All campaines purshause total
campaign_cols = [
    'accepted_campaign_1', 'accepted_campaign_2', 'accepted_campaign_3',
    'accepted_campaign_4', 'accepted_campaign_5', 'accepted_last_campaign'
] 
df['campaigns_accepted_count'] = df[campaign_cols].sum(axis=1)
df.drop(campaign_cols, axis=1, inplace=True)

# %%
row = df[df['annual_income'] == 82800]
print(row)
# Out:
#       birth_year education_level marital_status  annual_income  num_children  \
# 15          1946             PhD         Single        82800.0             0
# 1570        1946             PhD         Single        82800.0             0
#
#       num_teenagers  days_since_last_purchase  has_recent_complaint  \
# 15              0.0                        23                     0
# 1570            0.0                        23                     0
#
#       spend_wine  spend_fruits  spend_meat  spend_fish  spend_sweets  \
# 15          1006            22         115          59            68
# 1570        1006            22         115          59            68
#
#       spend_gold  num_discount_purchases  num_web_purchases  \
# 15            45                       1                  7
# 1570          45                       1                  7
#
#       num_catalog_purchases  num_store_purchases  web_visits_last_month  \
# ...

# %%
before = len(df)
df = df.drop_duplicates()
after = len(df)

print("Removed:", before - after, "duplicates")
# Out:
# Removed: 158 duplicates

# %%
row = df[df['annual_income'] == 82800]
print(row)
# Out:
#     birth_year education_level marital_status  annual_income  num_children  \
# 15        1946             PhD         Single        82800.0             0
#
#     num_teenagers  days_since_last_purchase  has_recent_complaint  spend_wine  \
# 15            0.0                        23                     0        1006
#
#     spend_fruits  spend_meat  spend_fish  spend_sweets  spend_gold  \
# 15            22         115          59            68          45
#
#     num_discount_purchases  num_web_purchases  num_catalog_purchases  \
# 15                       1                  7                      6
#
#     num_store_purchases  web_visits_last_month  campaigns_accepted_count
# 15                   12                      3                         3

# %%
# FIX: make df an independent copy
df = df.copy()

# 1. Missing indicators (so model knows value was missing)
df['education_missing'] = df['education_level'].isnull().astype(int)
df['income_missing'] = df['annual_income'].isnull().astype(int)
df['teen_missing'] = df['num_teenagers'].isnull().astype(int)

# 2. Impute categorical column
df['education_level'] = df['education_level'].fillna("Unknown")

# 3. Impute numeric columns with median
df['annual_income'] = df['annual_income'].fillna(df['annual_income'].median())
df['num_teenagers'] = df['num_teenagers'].fillna(df['num_teenagers'].median())

df.isnull().sum()
# Out:
# birth_year                  0
# education_level             0
# marital_status              0
# annual_income               0
# num_children                0
# num_teenagers               0
# days_since_last_purchase    0
# has_recent_complaint        0
# spend_wine                  0
# spend_fruits                0
# spend_meat                  0
# spend_fish                  0
# spend_sweets                0
# spend_gold                  0
# num_discount_purchases      0
# num_web_purchases           0
# num_catalog_purchases       0
# num_store_purchases         0
# web_visits_last_month       0
# campaigns_accepted_count    0
# education_missing           0
# income_missing              0
# teen_missing                0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

df = df.copy()

le = LabelEncoder()

for col in df.select_dtypes(include=['object']).columns: #object -> string || categorical data
    df[col + "_encoded"] = le.fit_transform(df[col])

print(df.head(10))
# Out:
#     birth_year education_level marital_status  annual_income  num_children  \
# 0         1957      Graduation         Single        58138.0             0
# 1         1954      Graduation         Single        46344.0             1
# 2         1965      Graduation       Together        71613.0             0
# 3         1984      Graduation       Together        26646.0             1
# 4         1981             PhD        Married        58293.0             1
# 5         1967          Master       Together        62513.0             0
# 6         1971      Graduation       Divorced        55635.0             0
# 8         1974             PhD       Together        30351.0             1
# 11        1976           Basic        Married         7500.0             0
# 12        1959      Graduation       Divorced        63033.0             0
#
#     num_teenagers  days_since_last_purchase  has_recent_complaint  spend_wine  \
# ...

# %%
df = df.drop(columns=["marital_status","education_level"])
df.tail(20)
# Out:
#       birth_year  annual_income  num_children  num_teenagers  \
# 2214        1976         5305.0             0            1.0
# 2215        1954        36807.0             1            1.0
# 2217        1948        82032.0             0            0.0
# 2219        1985        40101.0             1            0.0
# 2220        1979        58025.0             0            1.0
# 2222        1979         7500.0             1            0.0
# 2223        1963        33562.0             1            2.0
# 2224        1970        57642.0             0            1.0
# 2226        1979        63777.0             1            1.0
# 2227        1962        57967.0             0            1.0
# 2229        1972        24434.0             2            0.0
# 2230        1984        11012.0             1            0.0
# 2231        1970        44802.0             0            0.0
# 2232        1986        26816.0             0            0.0
# ...

# %%
from sklearn.feature_selection import VarianceThreshold
import pandas as pd

# Make a copy to keep things clean
df_fs = df.copy()

# ----- 1. Remove low-variance features -----
var_selector = VarianceThreshold(threshold=0.01)  # remove features with <1% variance
var_selector.fit(df_fs)

low_var_mask = var_selector.get_support()

df_lowvar = df_fs.loc[:, low_var_mask]

print("Removed features (low variance):")
print(df_fs.columns[~low_var_mask].tolist())
print("\nRemaining features:", df_lowvar.shape[1])
# Out:
# Removed features (low variance):
# ['has_recent_complaint', 'education_missing', 'income_missing', 'teen_missing']
#
# Remaining features: 19

# %%
import numpy as np

# ----- 2. Remove highly correlated features -----
corr_matrix = df_lowvar.corr().abs()

# Upper triangle of the correlation matrix
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(bool))

# Features to drop
to_drop = [column for column in upper.columns if any(upper[column] > 0.85)]

print("Highly correlated features removed:", to_drop)

df_corr = df_lowvar.drop(columns=to_drop)
# Out:
# Highly correlated features removed: []

# %%
from sklearn.cluster import KMeans

# Use the FINAL cleaned features to form clusters
kmeans = KMeans(n_clusters=3, random_state=42)
clusters = kmeans.fit_predict(df_corr)

# Add clusters to df_corr
df_corr["Cluster"] = clusters

# %%
from sklearn.feature_selection import SelectKBest, f_classif

# Target
y = df_corr["Cluster"]

# Features (drop target!)
X = df_corr.drop(columns=["Cluster"])

# Select best k features
k = 3
selector = SelectKBest(score_func=f_classif, k=k)
X_new = selector.fit_transform(X, y)

selected_mask = selector.get_support()
selected_features = X.columns[selected_mask]

print("Selected Features (ANOVA F-test):")
print(selected_features)
# Out:
# Selected Features (ANOVA F-test):
# Index(['annual_income', 'spend_wine', 'spend_meat'], dtype='object')

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np

# Extract features
X = df_corr[["annual_income", "spend_wine", "spend_meat"]]
labels = df_corr["Cluster"]

# Create a color map with strong contrast
colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728']  # blue, orange, green, red

fig = plt.figure(figsize=(14, 10))
ax = fig.add_subplot(111, projection="3d")

# Plot each cluster separately for clarity
for cluster_id in sorted(df_corr["Cluster"].unique()):
    subset = df_corr[df_corr["Cluster"] == cluster_id]
    ax.scatter(
        subset["annual_income"],
        subset["spend_wine"],
        subset["spend_meat"],
        s=60,
        alpha=0.85,
        color=colors[cluster_id % len(colors)],
        label=f"Cluster {cluster_id}",
        edgecolor="k",
        linewidth=0.4
    )

# Styling
ax.set_xlabel("Annual Income", fontsize=12)
ax.set_ylabel("Spend on Wine", fontsize=12)
ax.set_zlabel("Spend on Meat", fontsize=12)
ax.set_title("Enhanced 3D Visualization of Clusters", fontsize=15)

# Rotate for better angle
ax.view_init(elev=25, azim=135)

plt.legend()
plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import silhouette_score

# Use only the selected features
X_selected = df_corr[["annual_income", "spend_wine", "spend_meat"]]

# Clusters
labels = df_corr["Cluster"]

score = silhouette_score(X_selected, labels)
print("Silhouette Score:", score)
# Out:
# Silhouette Score: 0.5370698208511828

# %%
# =============================
#  SVM ONE-VS-ALL CLASSIFIER
# =============================

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.multiclass import OneVsRestClassifier
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report

# Attach KMeans cluster labels (NOT PCA)
df_corr["Cluster"]

# Target
y = df_corr["Cluster"]

# Features (drop target)
X = df_corr[[
    "annual_income",
    "spend_wine",
    "spend_meat"
]]

# Scale features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Train/test split
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y, test_size=0.2, random_state=42, stratify=y
)

# SVM OVA
svm_ova = OneVsRestClassifier(
    SVC(kernel="rbf", C=1.0, gamma="scale")
)

# Train
svm_ova.fit(X_train, y_train)

# Predict
y_pred = svm_ova.predict(X_test)

# Evaluate
print("Accuracy:", accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.9767441860465116
#               precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97       151
#            1       0.97      0.98      0.98       100
#            2       0.99      0.99      0.99       136
#
#     accuracy                           0.98       387
#    macro avg       0.98      0.98      0.98       387
# weighted avg       0.98      0.98      0.98       387

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(8,6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("SVM Confusion Matrix")
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure(figsize=(14,10))
ax = fig.add_subplot(111, projection='3d')

ax.scatter(
    df_corr.loc[y_test.index, "annual_income"],
    df_corr.loc[y_test.index, "spend_wine"],
    df_corr.loc[y_test.index, "spend_meat"],
    c=y_pred,
    cmap="tab10",
    s=60,
    alpha=0.8
)

ax.set_xlabel("Annual Income")
ax.set_ylabel("Spend on Wine")
ax.set_zlabel("Spend on Meat")
ax.set_title("SVM Predictions in 3D Feature Space")

plt.show()

# %%
import joblib

joblib.dump(kmeans, "kmeans.pkl")
joblib.dump(scaler, "scaler.pkl")
joblib.dump(var_selector, "variance_selector.pkl")

joblib.dump(svm_ova, "svm_ova.pkl")
joblib.dump(scaler, "svm_scaler.pkl")
joblib.dump(
    ["annual_income", "spend_wine", "spend_meat"],
    "svm_input_features.pkl"
)
# Out:
# ['svm_input_features.pkl']
